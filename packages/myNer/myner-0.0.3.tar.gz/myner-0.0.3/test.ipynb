# %%
from text_preprocessing import spacy_preprocessing 
from ner import ner_spacy,find_imo,find_swift,ner_dicts
from highlight_pdf import output
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def charge_text(text_file):
    file = text_file
    f=open(file,'r',encoding='utf8')
    text= f.read()
    return text

def get_entites(text):
    """
    Text is the text from wich we extract the entities
    """ 
    preprocessed_text = spacy_preprocessing(text,lowercase=True,punctuation=True)
    ents = list(ner_spacy(preprocessed_text)[0])
    ents.extend(find_imo(text))
    ents.extend(find_swift(text))
    ents.extend(ner_dicts(text,"postgresql://postgres:achraf@localhost:5432/ner_dicts","ports_banks_ships"))
    return ents

def test(text_file,pdf):
    text = charge_text(text_file)
    text_ents = get_entites(text)
    output(pdf)
    return "pdf highlighté, entité dans le texte sont {}".format(text_ents)

# %%
#test("C://Users/PC2//Downloads//26964649.txt","C://Users/PC2//Downloads//26964649.pdf")

# %%
def unique_ents(text):
    ents = get_entites(text)
    l=[ent.text for ent in ents]
    return list(set(l))

# %%
unique_ents(charge_text("C://Users/PC2//Downloads//26964649.txt"))
# Out:
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# ['18',
#  '111 km',
#  'bill lading  non',
#  '111',
#  'iid',
#  '40at',
#  '20220427',
#  '248',
#  '2s',
#  'mufg sank',
#  '17',
#  '0402143',
#  'morocco',
#  'l',
#  '608fd25 84266',
#  'article 24  nyk line',
#  'geean',
#  '1581058112',
#  '929049',
#  'ncgn ma  cas  cas  bay tine',
#  '608fd25 84200',
#  '460',
#  '4 608fd25 84179 1dz2 0401655',
#  'mufg bank  ltd',
#  'gag2ge67i',
#  'nagoya aichi  ',
#  '9 1  1  q',
#  '2',
#  '110',
#  '150  1068112',
#  'b111',
#  'aichi pref',
#  '480',
#  '14 608fd25 84293 1dzz 0402098',
#  'banques sa  df1',
#  'no00043cd100079125  non resident yen  ',
#  '55  boulevard',
#  'anb',
#  '1  2  1 m  ',
#  '84311 1dz',
#  '20500',
#  '28',
#  '0401963',
#  '1tt',
#  '12',
#  'jpy',
#  '8660',
#  '8',
#  '608fd25 84367 1dzz 0402231  3 608fd25 84181',
#  '0401959',
#  'stipulations',
#  '08',
#  '0402021',
#  '35',
#  '2o90',
#  '608fd25 84267 1dzz 0402024',
#  '20220511',
#  '0401771',
#  '10',
#  '501',
#  '20',
#  'days',
#  '20220510  date',
#  '05',
#  '608fd25 84307 1dz 0402079',
#  '448',
#  'zak',
#  'japan',
#  '00',
#  '7',
#  'fdf84548',
#  '40aj',
#  '13',
#  '77660',
#  '0401726',
#  '1  3  2  1  w  fy',
#  '8  mn',
#  '608fd25 84328 1dzz 0402143',
#  'oooascdr00079125',
#  '4  s',
#  'aichi pref  ',
#  '6',
#  '2022',
#  '1  3  2',
#  'ref',
#  '173060',
#  '35674000  marks',
#  '8  nd  ',
#  '20220517',
#  '1  2 1',
#  'nr13',
#  '608fd25 84367 1dz 0402231  3 608fd25',
#  '4  ay  ma  oo  gl',
#  '0522438888',
#  '7  moon  2 ee ee  ',
#  'non resident yen',
#  '3  3  ',
#  '0401891',
#  '1',
#  '0208',
#  '1  3 8  6',
#  '1dz',
#  'article 1b  30  mr  fdf84548  shipper  ',
#  '500',
#  'ga',
#  'cti',
#  'ccc ene gce',
#  '11500 km',
#  '192203',
#  '15',
#  '0',
#  '42000000',
#  'ec',
#  'morocco attn  ',
#  '80',
#  '9202',
#  'wil',
#  'fob nagoya  ',
#  'fngopcas',
#  '5 4  1 8  nn  s  ',
#  '674  000',
#  '608fd25 84179 1dz 0401655',
#  'ten4',
#  '5  ke  ',
#  '35674  000',
#  '24',
#  '00043cdi00079125',
#  '2022 02',
#  '4600 0098',
#  '59',
#  '0401832  7 608fd25 84218 1dzz 0401891',
#  'f22ho24',
#  'nl',
#  'fab bha',
#  '608fd25 84240 1dz',
#  'year  2022',
#  '35674000',
#  '06229',
#  '608fd25 84307 1dz',
#  '1058112 date',
#  'no110',
#  '1a',
#  '27',
#  'nagoya',
#  '608fd25 84328 1dz',
#  '608fd25 84240 1dzz 0401959  ',
#  '608fd25 84179 1dzz 0401655',
#  'bill lading  ',
#  '0402095',
#  '16',
#  '22',
#  '608fd25 84240 1dzz 0401959',
#  '4 608fd25 84179 1dzz 0401655',
#  '31184000  freight 4490000',
#  'kartya',
#  '25',
#  'valorem',
#  'toyota',
#  '1  1  m  ',
#  '2  4  4  epr84548  j',
#  'cho  kariya',
#  'nr131418',
#  '05 kg',
#  'ne bevennne',
#  '1  mark',
#  '0402273',
#  '1  non resident yen',
#  'sec',
#  '4',
#  '608fd25 84359',
#  '96',
#  '41  dhl',
#  'no00043cd1007125',
#  'geo la  n  guwgead',
#  'no001524502000008',
#  'article 24',
#  'aichi pref  country',
#  '9',
#  '21',
#  'ge',
#  '04020798',
#  'picinan invoice  ci ructions',
#  'date20220427',
#  'ysugiura  ',
#  '5',
#  '0401893',
#  '3  1  ro  ',
#  '7012',
#  '8111',
#  'nagoya nagoya',
#  '608fd25 84266 1dzz 0402021',
#  'ia',
#  'noo',
#  '8671',
#  '0202',
#  '2lma20500',
#  '90 days',
#  '02',
#  'article 18  30  toyota  ',
#  'nishiki',
#  '11',
#  '0401834',
#  'nwk',
#  '1418',
#  '008',
#  '7532',
#  '608fd25 84267 1d2 0402024',
#  'swift  botkjpjtngy',
#  '608fd25 84328 1dzz 0402143  ',
#  '61',
#  '608fd25 84367 1dzz 0402231  3 608fd25',
#  '38',
#  '85206',
#  '3',
#  '4  20220517',
#  '5 9',
#  '04',
#  '0401832  7 608fd25 84218 1dz',
#  '608fd25 84179 1d4z 0401655',
#  '0402149',
#  'zot ag',
#  '9 496',
#  'generale']

# %%
spacy_preprocessing(charge_text("C://Users/PC2//Downloads//26964649.txt"))
# Out:
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# 'ef  express worldwide    x07  2022  96  20 mydhl 10 f 3008217   mufg sank ltd  origin   expoat    bec    ishik    aaa 3  chome  ngo  480  8680 nagoya aichi  japan  tre  societe generale marocaine contact  1  banques sa   df1  immeuble ase crna  alliances bld yacoub el mansour  et angle rue ennarjis 20500  casablanca morocco attn  import sec   20500 casablanca  l morocco _ t  ncgn ma  cas  cas    bay tine  peo  shpt welght place  ref  150  1068112 b 05 kg 41  dhl rxpreee terms conditions carciage apply  wwwdhicoctieniexpreesieninpindehingne _ advices     contants  documents   lt lid  iid   _   wa   ybill 25 9283 7012  wm   2lma20500  42000000  nl   j  jdo1 4600 0098 6107 7532  aw 9 496  fold  22  withl  c    mufg bank  ltd   global business office  original 21  24 nishiki 3  chome  naka  ku  nagoya 460  8660 japan  swift  botkjpjtngy  e  quote ref   f150  1058112 date  2022  05  20  mail  societe generale marocaine de draft  banques sa   df1  immeuble jpy  35  674  000  00  alliances bld yacoub el mansour claim  et angle rue ennarjis 20500 jpy 35  674  000  00  casablanca morocco attn  import sec  interest  tel  0522438888  pla days     61 deduct chg  issuing bank  societe generale marocaine de  banques sa   casablanca  55  boulevard adbelmoumen  casablanca  morocco  l  c   cf 00043cd100079125  k   issuing date  2022  04  22 add chg  maturity  value date  2022  08  08  tenor  qdays shipment date dated   2022  05  10  drawer  toyota industries corporation net claim  jpy 35  674  000  00  relative documents attached  mail cert  insp   conf  draft inv   co  inv   b  e nnb  l anb ins   pkgl  w  wl  origin  cert  cert  cert   ist  7 23 4 7  party  onp 13  instruction party  pls pay jpy directly  thr yr correspondence japan maturity   special instruction   advised societe generale marocaine de banques sa    casablanca casablanca negotiation  payment  acceptance cable     20  2022    credit terws fulfilled   general instruction  1  present acceptance advise maturity case usance draft acceptance   2  certify terms conditions complied stated   3  certify endorsed reverse credit   4  i computer generated advice signature required   06229 wl  1581058112 tric0453 r  fdf84548 l   3   shipper  toyota  industries  corporation   2  1  toyoda  cho  kariya  aicht pref     448  8671 japan o 4       original   forwarding agents   consignee  _  order     societe  generale  marocaine   ban ques   notify party  forges  de  bazas   route  111  km  11500 km 10  500  lot  polygone  lots  nr131418   ice no001524502 008   maroc  pre  carrier vessel voy    ocean vessel vay   4  port loading  sanshin co  ltd  _  80   b  l   fngopcas 501  nks182080619   lo  fab bha  4t   sort  rezrra   nwk   nippon yusen kaisha  bill lading  tiable consigned order   ssel  apparent good order condition  non   pped peared ene   indiestedherefn  goods  packages  said contain goods  carried  subject terms conditions  shipped board vessel  carriage hereunder constitutes merchant acceptance stipulations   exceptions  terms conditions bill fully signed  contrary  local custom privilege notwithstanding  bill supersedes ail prior agreements  freight engagements goods  bill  duly endorsed negotiable   surrendered exchange goods delivery order  issued  sea waybill  bill negotiable document title delivery shall  named consignee production reasonable proof identity  required carrier  witness whereof  undersigned   behalf nippon yusen kaisha vessel andor owner  signed number  bills stated hereunder  tenor date  issued bill  lading  delivery original bill case   shall stand void   goliath leader nagoya   port discharge  2k final destination  merchunts reference   casablanca   wee marks  numbers t noof p  kgs   kind packages units  description goods gross weight measurement  co units   kgs   m3   desti  forges de bazas    shipper desire state   port d  embarquement     nagoya port  20  units   toyota  forklift     port de debarquement 27 as  proforma invoice    casablanca port   f22h024  d ...

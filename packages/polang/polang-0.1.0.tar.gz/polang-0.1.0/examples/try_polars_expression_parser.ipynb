# %%
import sys

import polars as pl
import numpy as np
from polang import polang
from pyparsing import *
from pyparsing import pyparsing_common as ppc

# %%
# Trigonometric functions
expr = polang("alias(sin(a), 'sinus of a')")
print(expr)

df = pl.DataFrame({"Time": np.linspace(0,1), "a": np.linspace(1,2), "b": np.linspace(2,3), "c": np.linspace(3,4)})
df.select([pl.all(), expr])
# Out:
# col("a").sin().alias("sinus of a")
# shape: (50, 5)
# ┌──────────┬──────────┬──────────┬──────────┬────────────┐
# │ Time     ┆ a        ┆ b        ┆ c        ┆ sinus of a │
# │ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---        │
# │ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64        │
# ╞══════════╪══════════╪══════════╪══════════╪════════════╡
# │ 0.0      ┆ 1.0      ┆ 2.0      ┆ 3.0      ┆ 0.841471   │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.020408 ┆ 1.020408 ┆ 2.020408 ┆ 3.020408 ┆ 0.852322   │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.040816 ┆ 1.040816 ┆ 2.040816 ┆ 3.040816 ┆ 0.862817   │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.061224 ┆ 1.061224 ┆ 2.061224 ┆ 3.061224 ┆ 0.872953   │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...      ┆ ...      ┆ ...      ┆ ...      ┆ ...        │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.938776 ┆ 1.938776 ┆ 2.938776 ┆ 3.938776 ┆ 0.933056   │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.959184 ┆ 1.959184 ┆ 2.959184 ┆ 3.959184 ┆ 0.925521   │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.979592 ┆ 1.979592 ┆ 2.979592 ┆ 3.979592 ┆ 0.9176     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.0      ┆ 2.0      ┆ 3.0      ┆ 4.0      ┆ 0.909297   │
# └──────────┴──────────┴──────────┴──────────┴────────────┘

# %%
# Derivative
expr = polang("shift(a, 1) - shift(a, -1)")
print(expr)

df = pl.DataFrame({"Time": np.linspace(0,1), "a": np.linspace(1,2), "b": np.linspace(2,3), "c": np.linspace(3,4)})
df.select([pl.all(), expr.alias("da/dt")])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/NENNIA/Projects/polang/examples/try_polars_expression_parser.ipynb Zelle 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/NENNIA/Projects/polang/examples/try_polars_expression_parser.ipynb#ch0000005?line=0'>1</a> # Derivative
# ----> <a href='vscode-notebook-cell:/Users/NENNIA/Projects/polang/examples/try_polars_expression_parser.ipynb#ch0000005?line=1'>2</a> expr = polang("shift(a, 1) - shift(a, -1)")
#       <a href='vscode-notebook-cell:/Users/NENNIA/Projects/polang/examples/try_polars_expression_parser.ipynb#ch0000005?line=2'>3</a> print(expr)
#       <a href='vscode-notebook-cell:/Users/NENNIA/Projects/polang/examples/try_polars_expression_parser.ipynb#ch0000005?line=4'>5</a> df = pl.DataFrame({"Time": np.linspace(0,1), "a": np.linspace(1,2), "b": np.linspace(2,3), "c": np.linspace(3,4)})
#
# File ~/mambaforge/envs/test/lib/python3.10/site-packages/polang/polars_expression_parser.py:161, in polang(s)
#     159 def polang(s: str) -> Expr:
#     160     parsed = make_polang().parseString(s)[0]
# --> 161     return parsed.eval()
#
# File ~/mambaforge/envs/test/lib/python3.10/site-packages/polang/polars_expression_parser.py:123, in Function.eval(self)
#     121 if self.arg is None:
#     122     return self.func()
# --> 123 return self.func(self.arg.eval())
#
# File ~/mambaforge/envs/test/lib/python3.10/site-packages/polars/internals/expr.py:1833, in Expr.shift(self, periods)
#    1803 def shift(self, periods: int = 1) -> Expr:
#    1804     """
#    1805     Shift the values by a given period and fill the parts that will be empty due to
#    1806     this operation with nulls.
#    (...)
#    1831
#    1832     """
# -> 1833     return wrap_expr(self._pyexpr.shift(periods))
#
# TypeError: argument 'periods': 'float' object cannot be interpreted as an integer
